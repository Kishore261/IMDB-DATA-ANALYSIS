# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishore261/IMDB-DATA-ANALYSIS/blob/main/imdbdatset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMDB  DATASET  ANALYSIS IN PYTHON

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/imdb_top_1000 (1).csv')

# %% [markdown]
# DATA PREVIEW

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.sample(5)
# Out:
#                                            Poster_Link         Series_Title  \
# 827  https://m.media-amazon.com/images/M/MV5BMTY2Nj...    Miller's Crossing
# 404  https://m.media-amazon.com/images/M/MV5BMzVjNz...             Rain Man
# 278  https://m.media-amazon.com/images/M/MV5BNDhmNT...      The Deer Hunter
# 929  https://m.media-amazon.com/images/M/MV5BMjRjOT...          Match Point
# 234  https://m.media-amazon.com/images/M/MV5BMTkxNz...  Million Dollar Baby
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 827          1990           R  115 min    Crime, Drama, Thriller          7.7
# 404          1988           U  133 min                     Drama          8.0
# 278          1978           A  183 min                Drama, War          8.1
# 929          2005           R  124 min  Drama, Romance, Thriller          7.6
# 234          2004          UA  132 min              Drama, Sport          8.1
#
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# DATA INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# DATA CLEANING

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.rename(columns={'IMDB_Ratings':'Ratings'},inplace=True)

# %% [markdown]
# Columns Analysis

# %%
df['Genre'].nunique()
# Out:
# 172

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Drama                        58
# Drama, Romance               26
# Comedy, Drama                24
# Crime, Drama, Thriller       22
# Action, Adventure, Sci-Fi    21
#                              ..
# Animation, Drama, Romance     1
# Action, Biography, Crime      1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Comedy, Music, Musical        1
# Name: count, Length: 172, dtype: int64

# %%
df['IMDB_Rating'].value_counts(normalize=True)
# Out:
# IMDB_Rating
# 7.7    0.169468
# 7.6    0.149860
# 7.8    0.149860
# 8.0    0.135854
# 7.9    0.107843
# 8.1    0.100840
# 8.3    0.046218
# 8.2    0.044818
# 8.4    0.028011
# 8.5    0.026611
# 8.6    0.015406
# 8.7    0.007003
# 8.8    0.007003
# 8.9    0.004202
# 9.0    0.004202
# 9.3    0.001401
# 9.2    0.001401
# Name: proportion, dtype: float64

# %%
df.select_dtypes(include=['object'])
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# GROUPING AND SORTING

# %%
df.groupby(['Genre','Certificate'])['IMDB_Rating'].mean()
# Out:
# Genre                      Certificate
# Action, Adventure          A              8.05
#                            U              8.20
#                            UA             8.30
# Action, Adventure, Comedy  A              7.70
#                            R              7.85
#                                           ...
# Mystery, Thriller          A              7.90
#                            U              8.40
#                            UA             8.40
# Western                    A              8.30
#                            U              8.40
# Name: IMDB_Rating, Length: 351, dtype: float64

# %%
df.sort_values(by='IMDB_Rating',ascending=False)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 4                12 Angry Men          1957           U   96 min
# ...

# %% [markdown]
# VISUALIZATION

# %%
sns.histplot(df['IMDB_Rating'])
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Count'>

# %%
df['Certificate'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Certificate'>

# %%
sns.scatterplot(x='IMDB_Rating',y='Meta_score',data=df)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Meta_score'>

# %%
sns.pairplot(df.select_dtypes(include='number'))

# %%
df.groupby('Released_Year')['IMDB_Rating'].sum().plot()
# Out:
# <Axes: xlabel='Released_Year'>

# %% [markdown]
# Visualize missing values(advanced)

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >
